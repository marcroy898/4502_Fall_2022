# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Data/raw-emdat-data.csv')
df
# Out:
#               Dis No  Year  Seq           Glide Disaster Group  \
# 0      2002-0122-AFG  2002  122             NaN        Natural
# 1      2002-0175-AFG  2002  175             NaN        Natural
# 2      2002-0208-AFG  2002  208             NaN        Natural
# 3      2002-0368-ARG  2002  368             NaN        Natural
# 4      2002-0082-BRA  2002   82             NaN        Natural
# ...              ...   ...  ...             ...            ...
# 13266  2022-0711-COD  2022  711             NaN  Technological
# 13267  2022-0569-ZWE  2022  569  EP-2022-000304        Natural
# 13268  2022-0216-ZWE  2022  216             NaN  Technological
# 13269  2022-0201-TLS  2022  201  EP-2022-000162        Natural
# 13270  2022-0650-SSD  2022  650             NaN        Natural
#
#       Disaster Subgroup           Disaster Type Disaster Subtype  \
# 0           Geophysical              Earthquake  Ground movement
# 1           Geophysical              Earthquake  Ground movement
# ...

# %%
print(df['Disaster Type'].unique())
print(df['Disaster Group'].unique())
print(df['Disaster Subtype'].unique())
# Out:
# ['Earthquake' 'Flood' 'Landslide' 'Storm' 'Drought' 'Epidemic'
#  'Transport accident' 'Miscellaneous accident' 'Extreme temperature'
#  'Wildfire' 'Industrial accident' 'Mass movement (dry)'
#  'Volcanic activity' 'Complex Disasters' 'Insect infestation' 'Impact'
#  'Animal accident' 'Glacial lake outburst']
# ['Natural' 'Technological' 'Complex Disasters']
# ['Ground movement' 'Riverine flood' 'Mudslide' nan 'Convective storm'
#  'Drought' 'Avalanche' 'Bacterial disease' 'Parasitic disease'
#  'Viral disease' 'Road' 'Explosion' 'Air' 'Collapse' 'Cold wave'
#  'Land fire (Brush, Bush, Pasture)' 'Extra-tropical storm' 'Water'
#  'Flash flood' 'Tropical cyclone' 'Rail' 'Other' 'Fire' 'Forest fire'
#  'Landslide' 'Poisoning' 'Tsunami' 'Coastal flood' 'Heat wave' 'Gas leak'
#  'Chemical spill' 'Ash fall' 'Famine' 'Locust' 'Severe winter conditions'
#  'Radiation' 'Oil spill' 'Rockfall' 'Lava flow' 'Pyroclastic flow']

# %%
relevant_disasters = ['Oil spill','Chemical spill','Severe winter conditions','Heat wave', 'Gas leak', 'Tsunami', 
                      'Tropical cyclone','Extra-tropical storm', 'Cold wave', 'Ground movement']
df_rel = df[df['Disaster Subtype'].isin(relevant_disasters)]
print(len(df_rel))
# Out:
# 2288

# %%
df_rel.columns
# Out:
# Index(['Dis No', 'Year', 'Seq', 'Glide', 'Disaster Group', 'Disaster Subgroup',
#        'Disaster Type', 'Disaster Subtype', 'Disaster Subsubtype',
#        'Event Name', 'Country', 'ISO', 'Region', 'Continent', 'Location',
#        'Origin', 'Associated Dis', 'Associated Dis2', 'OFDA Response',
#        'Appeal', 'Declaration', 'AID Contribution ('000 US$)', 'Dis Mag Value',
#        'Dis Mag Scale', 'Latitude', 'Longitude', 'Local Time', 'River Basin',
#        'Start Year', 'Start Month', 'Start Day', 'End Year', 'End Month',
#        'End Day', 'Total Deaths', 'No Injured', 'No Affected', 'No Homeless',
#        'Total Affected', 'Reconstruction Costs ('000 US$)',
#        'Reconstruction Costs, Adjusted ('000 US$)',
#        'Insured Damages ('000 US$)', 'Insured Damages, Adjusted ('000 US$)',
#        'Total Damages ('000 US$)', 'Total Damages, Adjusted ('000 US$)', 'CPI',
#        'Adm Level', 'Admin1 Code', 'Admin2 Code', 'Geo Locations'],
#       dtype='object')

# %%
df_rel.to_csv('../Data/emdat_data/raw-emdat-data.csv')
